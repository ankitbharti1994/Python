# %%
import pandas as pd

# %%
# Method 1: Specify the full path of a file

# %%
stats = pd.read_csv('/Users/ankitkumarbharti/Desktop/Practice/Python/Udemy Learning/Demographic-Data.csv')

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
import os

# %%
print(os.getcwd())
# Out:
# /Users/ankitkumarbharti/Desktop/Practice/Python/Udemy Learning

# %%
os.chdir('/Users/ankitkumarbharti/Desktop/')

# %%
os.getcwd()
# Out:
# '/Users/ankitkumarbharti/Desktop'

# %%
os.chdir('/Users/ankitkumarbharti/Desktop/Practice/Python/Udemy Learning/')

# %%
os.getcwd()
# Out:
# '/Users/ankitkumarbharti/Desktop/Practice/Python/Udemy Learning'

# %%
pd.read_csv('Demographic-Data.csv')
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
os.getcwd()
# Out:
# '/Users/ankitkumarbharti/Desktop/Practice/Python/Udemy Learning'

# %%
pd.read_csv('Demographic-Data.csv')
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
data = pd.read_csv('Demographic-Data.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
data[0:len(data): 20]
# Out:
#     Country Name Country Code  Birth rate  Internet users         Income Group
# 0          Aruba          ABW      10.244         78.9000          High income
# 20       Belarus          BLR      12.500         54.1700  Upper middle income
# 40    Costa Rica          CRI      15.022         45.9600  Upper middle income
# 60         Gabon          GAB      30.555          9.2000  Upper middle income
# 80         India          IND      20.291         15.1000  Lower middle income
# 100        Libya          LBY      21.425         16.5000  Upper middle income
# 120   Mozambique          MOZ      39.705          5.4000           Low income
# 140       Poland          POL       9.600         62.8492          High income
# 160     Suriname          SUR      18.455         37.4000  Upper middle income
# 180      Uruguay          URY      14.374         57.6900          High income

# %%
data.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
       'IncomeGroup']

# %%
data
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
data['Multiplication'] = data.BirthRate * data.InternetUsers

# %%
data
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  Multiplication
# 0            High income        808.2516
# 1             Low income        207.9927
# 2    Upper middle income        878.3135
# ...

# %%
data.to_csv('main-data.csv')

# %%
mainData = pd.read_csv('main-data.csv')

# %%
mainData
# Out:
#      Unnamed: 0           CountryName CountryCode  BirthRate  InternetUsers  \
# 0             0                 Aruba         ABW     10.244           78.9
# 1             1           Afghanistan         AFG     35.253            5.9
# 2             2                Angola         AGO     45.985           19.1
# 3             3               Albania         ALB     12.877           57.2
# 4             4  United Arab Emirates         ARE     11.044           88.0
# ..          ...                   ...         ...        ...            ...
# 190         190           Yemen, Rep.         YEM     32.947           20.0
# 191         191          South Africa         ZAF     20.850           46.5
# 192         192      Congo, Dem. Rep.         COD     42.394            2.2
# 193         193                Zambia         ZMB     40.471           15.4
# 194         194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  Multiplication
# ...

# %%
mainData = mainData.drop('Multiplication', 1)

# %%
mainData
# Out:
#      Unnamed: 0           CountryName CountryCode  BirthRate  InternetUsers  \
# 0             0                 Aruba         ABW     10.244           78.9
# 1             1           Afghanistan         AFG     35.253            5.9
# 2             2                Angola         AGO     45.985           19.1
# 3             3               Albania         ALB     12.877           57.2
# 4             4  United Arab Emirates         ARE     11.044           88.0
# ..          ...                   ...         ...        ...            ...
# 190         190           Yemen, Rep.         YEM     32.947           20.0
# 191         191          South Africa         ZAF     20.850           46.5
# 192         192      Congo, Dem. Rep.         COD     42.394            2.2
# 193         193                Zambia         ZMB     40.471           15.4
# 194         194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# ...

# %%
mainData.to_csv('main-data.csv')

# %%
mainData = pd.read_csv('main-data.csv')

# %%
mainData
# Out:
#      Unnamed: 0  Unnamed: 0.1           CountryName CountryCode  BirthRate  \
# 0             0             0                 Aruba         ABW     10.244
# 1             1             1           Afghanistan         AFG     35.253
# 2             2             2                Angola         AGO     45.985
# 3             3             3               Albania         ALB     12.877
# 4             4             4  United Arab Emirates         ARE     11.044
# ..          ...           ...                   ...         ...        ...
# 190         190           190           Yemen, Rep.         YEM     32.947
# 191         191           191          South Africa         ZAF     20.850
# 192         192           192      Congo, Dem. Rep.         COD     42.394
# 193         193           193                Zambia         ZMB     40.471
# 194         194           194              Zimbabwe         ZWE     35.715
#
#      InternetUsers          IncomeGroup
# ...

# %%
mainData[mainData.BirthRate > 40]
# Out:
#      Unnamed: 0  Unnamed: 0.1       CountryName CountryCode  BirthRate  \
# 2             2             2            Angola         AGO     45.985
# 11           11            11           Burundi         BDI     44.151
# 14           14            14      Burkina Faso         BFA     40.551
# 65           65            65       Gambia, The         GMB     42.525
# 115         115           115              Mali         MLI     44.138
# 127         127           127             Niger         NER     49.661
# 128         128           128           Nigeria         NGA     40.045
# 156         156           156           Somalia         SOM     43.891
# 167         167           167              Chad         TCD     45.745
# 178         178           178            Uganda         UGA     43.474
# 192         192           192  Congo, Dem. Rep.         COD     42.394
# 193         193           193            Zambia         ZMB     40.471
#
#      InternetUsers          IncomeGroup
# ...

# %%
filter1 = mainData.BirthRate > 40

# %%
filter2 = mainData.InternetUsers < 2

# %%
filter1
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193     True
# 194    False
# Name: BirthRate, Length: 195, dtype: bool

# %%
filter2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
mainData[filter1 & filter2]
# Out:
#      Unnamed: 0  Unnamed: 0.1 CountryName CountryCode  BirthRate  \
# 11           11            11     Burundi         BDI     44.151
# 127         127           127       Niger         NER     49.661
# 156         156           156     Somalia         SOM     43.891
#
#      InternetUsers IncomeGroup
# 11             1.3  Low income
# 127            1.7  Low income
# 156            1.5  Low income

# %%
mainData[mainData.IncomeGroup == 'High income']
# Out:
#      Unnamed: 0  Unnamed: 0.1            CountryName CountryCode  BirthRate  \
# 0             0             0                  Aruba         ABW     10.244
# 4             4             4   United Arab Emirates         ARE     11.044
# 5             5             5              Argentina         ARG     17.716
# 7             7             7    Antigua and Barbuda         ATG     16.447
# 8             8             8              Australia         AUS     13.200
# ..          ...           ...                    ...         ...        ...
# 174         174           174    Trinidad and Tobago         TTO     14.590
# 180         180           180                Uruguay         URY     14.374
# 181         181           181          United States         USA     12.500
# 184         184           184          Venezuela, RB         VEN     19.842
# 185         185           185  Virgin Islands (U.S.)         VIR     10.700
#
#      InternetUsers  IncomeGroup
# ...

# %%
mainData.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
mainData.CountryName.unique()
# Out:
# array(['Aruba', 'Afghanistan', 'Angola', 'Albania',
#        'United Arab Emirates', 'Argentina', 'Armenia',
#        'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan',
#        'Burundi', 'Belgium', 'Benin', 'Burkina Faso', 'Bangladesh',
#        'Bulgaria', 'Bahrain', 'Bahamas, The', 'Bosnia and Herzegovina',
#        'Belarus', 'Belize', 'Bermuda', 'Bolivia', 'Brazil', 'Barbados',
#        'Brunei Darussalam', 'Bhutan', 'Botswana',
#        'Central African Republic', 'Canada', 'Switzerland', 'Chile',
#        'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Rep.', 'Colombia',
#        'Comoros', 'Cabo Verde', 'Costa Rica', 'Cuba', 'Cayman Islands',
#        'Cyprus', 'Czech Republic', 'Germany', 'Djibouti', 'Denmark',
#        'Dominican Republic', 'Algeria', 'Ecuador', 'Egypt, Arab Rep.',
#        'Eritrea', 'Spain', 'Estonia', 'Ethiopia', 'Finland', 'Fiji',
#        'France', 'Micronesia, Fed. Sts.', 'Gabon', 'United Kingdom',
# ...

# %%
mainData[mainData.CountryName == 'Malta']
# Out:
#      Unnamed: 0  Unnamed: 0.1 CountryName CountryCode  BirthRate  \
# 116         116           116       Malta         MLT        9.5
#
#      InternetUsers  IncomeGroup
# 116        68.9138  High income

# %%
import matplotlib.pyplot as mpt
# %matplotlib inline

# %%
import seaborn as sbn
mpt.rcParams['figure.figsize'] = 15, 5

# %%
distribution = sbn.distplot(mainData.InternetUsers, bins=30)

# %%
dis = sbn.boxplot(data=mainData, x='IncomeGroup', y='BirthRate')
